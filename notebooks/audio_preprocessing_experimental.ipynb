# %% [markdown]
# # Audio Preprocessing Experiments
#
# This notebook is used for testing and prototyping preprocessing logic
# before integrating it into the main `src/` Python modules.
#
# **Note:** This is not part of the production code.
# Some code cells may be exploratory or not well-documented.

# %%
import tensorflow as tf 
import keras
import librosa
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as dis

# %%
file_path = "C:/voice-speaker-binary-classifier/data/"

# %%
# Load datasets with inferred lables
dataset = keras.utils.audio_dataset_from_directory(
    directory=file_path,
    labels="inferred",
    label_mode="int",
    # sampling_rate=16000,
    shuffle=True,
    output_sequence_length=48000,
    seed=1337
)
# Out:
# Found 863 files belonging to 2 classes.

# %%
# Split to train and validation set

dataset_size = dataset.cardinality().numpy()
train_size = int(0.8 * dataset_size)

train_ds = dataset.take(train_size)
test_ds = dataset.skip(train_size)

# %%
def add_noise(audio_batch, noise_factor=None):
    """
    Add random Gaussian noise to audio signal.

    Args:
        audio (np.ndarray): Orginal audio waveform.
        noise_factor (float): Controls noise intensity.

    Returns:
        np.ndarray: Noisy audio.    
    """
    
    noise = np.random.randn(audio_batch.shape[0], audio_batch.shape[1], audio_batch.shape[2])

    if noise_factor is None:
        noise_factor = np.random.uniform(0.001, 0.01)

    scaled_noise = noise_factor * noise
    
    augmented_audio = scaled_noise + audio_batch
    # Clip to maintain [-1, 1] range for audio
    return np.clip(augmented_audio, -1.0, 1.0)

# %%
def pitch_shift(audio, sr, n_steps=None):
    """
    Pitch shift audio by n_steps semitones.

    Args:
        audio (np.ndarray): Audio waveform.
        sr (int): Sampling rate.
        n_steps (int): Number of semitones to shift (positive or negative).

    Returns:
        np.ndarray: Pitch shifted audio.    
    """

    if n_steps is None:
        n_steps = np.random.randint(-3, 4, size=audio.shape[0])
    return np.stack([
        librosa.effects.pitch_shift(audio.flatten(), sr=sr, n_steps=int(step))
        for audio, step in zip(audio, n_steps)
    ])

# %%
def amplitude_scaling(audio, scale=None):
    """
    Scale amplitude (volume) of audio.

    Args:
        audio (np.ndarray): Audio waveform.
        scale (float): Amplitude scaled audio.

    Returns:
        np.ndarray: Amplitude scaled audio.    
    """

    if scale is None:
        scale = np.random.uniform(0.6, 1.2, size=audio.shape[0])

    return np.stack([
        np.clip((audio * scale), -1.0, 1.0) 
        for audio, scale in zip(audio, scale)
    ])

# %%
def random_augment(audio, sr):
    """
    Apply a random subset of augmentations to audio waveform.

    Args:
        audio (np.ndarray): Original audio waveform.
        sr (int): Sample rate

    Returns:
        augmented_audio (np.ndarray): augmented audio waveform.    
    """

    augmented = audio.copy()

    # Define probabilities of each augmentation.
    augmentations = [
        ("noise", 0.5, lambda x: (print("Calling noise func"), add_noise(x))[1]),
        ("pitch", 0.5, lambda x: (print("Calling pitch func"), pitch_shift(x, sr))[1]),
        ("amplitude", 0.5, lambda x: (print("Calling amplitude func"), amplitude_scaling(x))[1]),
    ]

    # Randomly apply augmentations based on probabilities
    for name, p, func in augmentations:
        if np.random.random() < p:
            try:
                augmented = func(audio)
            except Exception as e:
                print(f"Warning: augmentation {name} failed with error {e}")
    
    return augmented

# %%
def vtlp(melspectrogram, alpha=0.9):
    """
    Apply Vocal Tract Length Perturbation (VTLP) by wraping mel-spectrogram 
    frequency axis.

    Args:
        melspectrogram (np.ndarray): Mel spectrogram (freq x time).
        aplha (float): Wraping factor ~0.9-1.1, controls frequency scaling.

    Returns:
        np.ndarray: Warped mel spectrogram.    
    """

    num_freq_bins = melspectrogram.shape[0]
    warped_mel = np.zeros_like(melspectrogram)

    # Piecewise linear warping parameters
    f0 = int(num_freq_bins * 0.4)  # Frequency boundary point ~40% of bins
    for i in range(num_freq_bins):
        if i <= f0:
            warped_i = int(alpha * i)
        else:
            warped_i = int((num_freq_bins - alpha * f0) / (num_freq_bins - f0) * (i - f0) + alpha * f0)    
        warped_i = min(warped_i, num_freq_bins - 1)
        warped_mel[i, :] = melspectrogram[warped_i, :]
    return warped_mel

# %%
def waveform_to_mel(audio, sr=16000, n_mels=64, n_fft=1024, hop_length=256):
    """
    Convert waveform to mel-spectrogram.

    Args:
        audio (np.ndarray): Audio waveform.
        sr (int): Sampling rate.
        n_mels (int): Number of mel bins.
        n_fft (int): FFT window size.
        hop_length (int): Hop length for STFT.

    Returns:
        np.ndarray: Mel spectrogram (batch, n_mels, timie, 1).    
    """

    mel_specs = []

    for i in range(audio.shape[0]):
        sample = audio[i].squeeze()

        mel_spec = librosa.feature.melspectrogram(
            y=sample,
            sr=sr,
            n_mels=n_mels,
            n_fft=n_fft,
            hop_length=hop_length
        )
        mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)  # Convert to decibel scale.
        mel_specs.append(mel_spec_db)

        if i%10 == 0:
            print(f"Converted {i} samples to mel-spectrogram, remaining {audio.shape[0]-i}")
    
    mel_specs = np.array(mel_specs)
    print(f"Convertion completed!")
    mel_specs = mel_specs[..., np.newaxis]
    mel_specs = (mel_specs - mel_specs.min()) / (mel_specs.max() - mel_specs.min() + 1e-9)
    return mel_specs

# %%
def time_frequency_masking(mel_spectrogram, time_mask_param=(5, 20), freq_mask_param=(3, 12)):
    """
    Apply SpecAugment style time and frequency masking on mel spectrogram.
    
    Args:
        mel_spectrogram (np.ndarray): Mel spectrogram input.
        time_mask_param (int): Max width of time mask.
        freq_mask_param (int): Max width of frequency mask.
        
    Returns:
        np.ndarray: Masked mel spectrogram.
    """
    augmented = mel_spectrogram.copy()
    num_freq, num_time, _ = augmented.shape
    time_mask_param = np.random.randint(*time_mask_param)
    
    # Time masking
    if np.random.rand() < 0.5:
        t = np.random.randint(0, time_mask_param)
        t0 = np.random.randint(0, max(1, num_time - t))
        augmented[:, t0:t0+t] = 0
    
    # Frequency masking
    if np.random.rand() < 0.5:
        freq_mask_param = np.random.randint(*freq_mask_param)
        f = np.random.randint(0, freq_mask_param)
        f0 = np.random.randint(0, max(1, num_freq - f))
        augmented[f0:f0+f, :] = 0
    else:
        t = np.random.randint(0, time_mask_param)
        t0 = np.random.randint(0, max(1, num_time - t))
        augmented[:, t0:t0+t] = 0    
    
    return augmented

# %%
def pas(mel):

    augmented_batch = []

    # Define augmentation functions with probabilities
    augmentations = [
        ("masking", 0.5, lambda x: (print("Calling masking func"), time_frequency_masking(x))[1]),
        ("vtlp", 0.5, lambda x: (print("Calling vtlp func"), vtlp(x))[1]),
    ]

    # Loop over each sample
    for i, sample in enumerate(mel):
        augmented = sample.copy()
        # Loop through each augmentation
        for name, p, func in augmentations:
            if np.random.random() < p:
                try:
                    augmented = func(augmented)  # apply augmentation to this sample
                except Exception as e:
                    print(f"Warning: augmentation {name} failed for sample {i} with error {e}")

        # Make sure the shape is consistent (add channel dimension if needed)
        if augmented.ndim == 1:
            augmented = np.expand_dims(augmented, axis=-1)  # 

        augmented_batch.append(augmented)

    return np.stack(augmented_batch)

# %%
x_list = []
y_list = []

for x_batch, y_batch in train_ds.as_numpy_iterator():
    x_list.append(x_batch)
    y_list.append(y_batch)

x_train = np.array(x_list)
y_train = np.array(y_list)

# %%
x_train.shape
# Out:
# (21, 32, 48000, 1)

# %%
augg = []

num_aug = 4

for _ in range(num_aug):
    aug = np.stack([
        random_augment(x_train[i], sr=16000).reshape(x_train.shape[1], 48000, 1)
        for i in range(x_train.shape[0])
    ])
    augg.append(aug)
aug = np.stack(augg)
# Out:
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling noise func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling pitch func
# Calling amplitude func
# Calling amplitude func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling amplitude func
# Calling pitch func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling amplitude func
# Calling pitch func
# Calling noise func
# Calling amplitude func
# Calling noise func
# Calling noise func
# Calling amplitude func
# Calling amplitude func
# Calling amplitude func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling noise func
# Calling noise func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling pitch func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling amplitude func
# Calling noise func
# Calling amplitude func
# Calling pitch func
# Calling pitch func
# Calling amplitude func
# Calling noise func
# Calling amplitude func
# Calling pitch func
# Calling amplitude func
# Calling noise func
# Calling amplitude func
# Calling pitch func
# Calling pitch func
# Calling noise func
# Calling amplitude func
# Calling pitch func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling noise func
# Calling amplitude func
# Calling noise func
# Calling amplitude func
# Calling noise func
# Calling amplitude func
# Calling noise func
# Calling noise func
# Calling amplitude func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling amplitude func
# Calling noise func
# Calling noise func
# Calling pitch func
# Calling pitch func
# Calling amplitude func
# Calling amplitude func
# Calling amplitude func
# Calling noise func
# Calling pitch func
# Calling noise func
# Calling amplitude func
# Calling noise func
# Calling amplitude func
# Calling amplitude func
# Calling pitch func

# %%
x_train_flat = x_train.reshape(-1, 48000, 1)
aug_flat = aug.reshape(-1, 48000, 1)

all_samples_y = np.tile(y_train, num_aug + 1) # +1 for the original sample
all_samples_x = np.concatenate([x_train_flat, aug_flat], axis=0)

indices = np.arange(all_samples_x.shape[0])
np.random.shuffle(indices)

x_train = all_samples_x[indices]
y_train = all_samples_y[indices]
print(x_train.shape, y_train.shape)
# Out:
# (3360, 48000, 1) (3360,)

# %%
mel_spectro = waveform_to_mel(x_train, sr=16000)
aug_mel = pas(mel_spectro)
# Out:
# Converted 0 samples to mel-spectrogram, remaining 3360
# Converted 10 samples to mel-spectrogram, remaining 3350
# Converted 20 samples to mel-spectrogram, remaining 3340
# Converted 30 samples to mel-spectrogram, remaining 3330
# Converted 40 samples to mel-spectrogram, remaining 3320
# Converted 50 samples to mel-spectrogram, remaining 3310
# Converted 60 samples to mel-spectrogram, remaining 3300
# Converted 70 samples to mel-spectrogram, remaining 3290
# Converted 80 samples to mel-spectrogram, remaining 3280
# Converted 90 samples to mel-spectrogram, remaining 3270
# Converted 100 samples to mel-spectrogram, remaining 3260
# Converted 110 samples to mel-spectrogram, remaining 3250
# Converted 120 samples to mel-spectrogram, remaining 3240
# Converted 130 samples to mel-spectrogram, remaining 3230
# Converted 140 samples to mel-spectrogram, remaining 3220
# Converted 150 samples to mel-spectrogram, remaining 3210
# Converted 160 samples to mel-spectrogram, remaining 3200
# Converted 170 samples to mel-spectrogram, remaining 3190
# Converted 180 samples to mel-spectrogram, remaining 3180
# Converted 190 samples to mel-spectrogram, remaining 3170
# Converted 200 samples to mel-spectrogram, remaining 3160
# Converted 210 samples to mel-spectrogram, remaining 3150
# Converted 220 samples to mel-spectrogram, remaining 3140
# Converted 230 samples to mel-spectrogram, remaining 3130
# Converted 240 samples to mel-spectrogram, remaining 3120
# Converted 250 samples to mel-spectrogram, remaining 3110
# Converted 260 samples to mel-spectrogram, remaining 3100
# Converted 270 samples to mel-spectrogram, remaining 3090
# Converted 280 samples to mel-spectrogram, remaining 3080
# Converted 290 samples to mel-spectrogram, remaining 3070
# Converted 300 samples to mel-spectrogram, remaining 3060
# Converted 310 samples to mel-spectrogram, remaining 3050
# Converted 320 samples to mel-spectrogram, remaining 3040
# Converted 330 samples to mel-spectrogram, remaining 3030
# Converted 340 samples to mel-spectrogram, remaining 3020
# Converted 350 samples to mel-spectrogram, remaining 3010
# Converted 360 samples to mel-spectrogram, remaining 3000
# Converted 370 samples to mel-spectrogram, remaining 2990
# Converted 380 samples to mel-spectrogram, remaining 2980
# Converted 390 samples to mel-spectrogram, remaining 2970
# Converted 400 samples to mel-spectrogram, remaining 2960
# Converted 410 samples to mel-spectrogram, remaining 2950
# Converted 420 samples to mel-spectrogram, remaining 2940
# Converted 430 samples to mel-spectrogram, remaining 2930
# Converted 440 samples to mel-spectrogram, remaining 2920
# Converted 450 samples to mel-spectrogram, remaining 2910
# Converted 460 samples to mel-spectrogram, remaining 2900
# Converted 470 samples to mel-spectrogram, remaining 2890
# Converted 480 samples to mel-spectrogram, remaining 2880
# Converted 490 samples to mel-spectrogram, remaining 2870
# Converted 500 samples to mel-spectrogram, remaining 2860
# Converted 510 samples to mel-spectrogram, remaining 2850
# Converted 520 samples to mel-spectrogram, remaining 2840
# Converted 530 samples to mel-spectrogram, remaining 2830
# Converted 540 samples to mel-spectrogram, remaining 2820
# Converted 550 samples to mel-spectrogram, remaining 2810
# Converted 560 samples to mel-spectrogram, remaining 2800
# Converted 570 samples to mel-spectrogram, remaining 2790
# Converted 580 samples to mel-spectrogram, remaining 2780
# Converted 590 samples to mel-spectrogram, remaining 2770
# Converted 600 samples to mel-spectrogram, remaining 2760
# Converted 610 samples to mel-spectrogram, remaining 2750
# Converted 620 samples to mel-spectrogram, remaining 2740
# Converted 630 samples to mel-spectrogram, remaining 2730
# Converted 640 samples to mel-spectrogram, remaining 2720
# Converted 650 samples to mel-spectrogram, remaining 2710
# Converted 660 samples to mel-spectrogram, remaining 2700
# Converted 670 samples to mel-spectrogram, remaining 2690
# Converted 680 samples to mel-spectrogram, remaining 2680
# Converted 690 samples to mel-spectrogram, remaining 2670
# Converted 700 samples to mel-spectrogram, remaining 2660
# Converted 710 samples to mel-spectrogram, remaining 2650
# Converted 720 samples to mel-spectrogram, remaining 2640
# Converted 730 samples to mel-spectrogram, remaining 2630
# Converted 740 samples to mel-spectrogram, remaining 2620
# Converted 750 samples to mel-spectrogram, remaining 2610
# Converted 760 samples to mel-spectrogram, remaining 2600
# Converted 770 samples to mel-spectrogram, remaining 2590
# Converted 780 samples to mel-spectrogram, remaining 2580
# Converted 790 samples to mel-spectrogram, remaining 2570
# Converted 800 samples to mel-spectrogram, remaining 2560
# Converted 810 samples to mel-spectrogram, remaining 2550
# Converted 820 samples to mel-spectrogram, remaining 2540
# Converted 830 samples to mel-spectrogram, remaining 2530
# Converted 840 samples to mel-spectrogram, remaining 2520
# Converted 850 samples to mel-spectrogram, remaining 2510
# Converted 860 samples to mel-spectrogram, remaining 2500
# Converted 870 samples to mel-spectrogram, remaining 2490
# Converted 880 samples to mel-spectrogram, remaining 2480
# Converted 890 samples to mel-spectrogram, remaining 2470
# Converted 900 samples to mel-spectrogram, remaining 2460
# Converted 910 samples to mel-spectrogram, remaining 2450
# Converted 920 samples to mel-spectrogram, remaining 2440
# Converted 930 samples to mel-spectrogram, remaining 2430
# Converted 940 samples to mel-spectrogram, remaining 2420
# Converted 950 samples to mel-spectrogram, remaining 2410
# Converted 960 samples to mel-spectrogram, remaining 2400
# Converted 970 samples to mel-spectrogram, remaining 2390
# Converted 980 samples to mel-spectrogram, remaining 2380
# Converted 990 samples to mel-spectrogram, remaining 2370
# Converted 1000 samples to mel-spectrogram, remaining 2360
# Converted 1010 samples to mel-spectrogram, remaining 2350
# Converted 1020 samples to mel-spectrogram, remaining 2340
# Converted 1030 samples to mel-spectrogram, remaining 2330
# Converted 1040 samples to mel-spectrogram, remaining 2320
# Converted 1050 samples to mel-spectrogram, remaining 2310
# Converted 1060 samples to mel-spectrogram, remaining 2300
# Converted 1070 samples to mel-spectrogram, remaining 2290
# Converted 1080 samples to mel-spectrogram, remaining 2280
# Converted 1090 samples to mel-spectrogram, remaining 2270
# Converted 1100 samples to mel-spectrogram, remaining 2260
# Converted 1110 samples to mel-spectrogram, remaining 2250
# Converted 1120 samples to mel-spectrogram, remaining 2240
# Converted 1130 samples to mel-spectrogram, remaining 2230
# Converted 1140 samples to mel-spectrogram, remaining 2220
# Converted 1150 samples to mel-spectrogram, remaining 2210
# Converted 1160 samples to mel-spectrogram, remaining 2200
# Converted 1170 samples to mel-spectrogram, remaining 2190
# Converted 1180 samples to mel-spectrogram, remaining 2180
# Converted 1190 samples to mel-spectrogram, remaining 2170
# Converted 1200 samples to mel-spectrogram, remaining 2160
# Converted 1210 samples to mel-spectrogram, remaining 2150
# Converted 1220 samples to mel-spectrogram, remaining 2140
# Converted 1230 samples to mel-spectrogram, remaining 2130
# Converted 1240 samples to mel-spectrogram, remaining 2120
# Converted 1250 samples to mel-spectrogram, remaining 2110
# Converted 1260 samples to mel-spectrogram, remaining 2100
# Converted 1270 samples to mel-spectrogram, remaining 2090
# Converted 1280 samples to mel-spectrogram, remaining 2080
# Converted 1290 samples to mel-spectrogram, remaining 2070
# Converted 1300 samples to mel-spectrogram, remaining 2060
# Converted 1310 samples to mel-spectrogram, remaining 2050
# Converted 1320 samples to mel-spectrogram, remaining 2040
# Converted 1330 samples to mel-spectrogram, remaining 2030
# Converted 1340 samples to mel-spectrogram, remaining 2020
# Converted 1350 samples to mel-spectrogram, remaining 2010
# Converted 1360 samples to mel-spectrogram, remaining 2000
# Converted 1370 samples to mel-spectrogram, remaining 1990
# Converted 1380 samples to mel-spectrogram, remaining 1980
# Converted 1390 samples to mel-spectrogram, remaining 1970
# Converted 1400 samples to mel-spectrogram, remaining 1960
# Converted 1410 samples to mel-spectrogram, remaining 1950
# Converted 1420 samples to mel-spectrogram, remaining 1940
# Converted 1430 samples to mel-spectrogram, remaining 1930
# Converted 1440 samples to mel-spectrogram, remaining 1920
# Converted 1450 samples to mel-spectrogram, remaining 1910
# Converted 1460 samples to mel-spectrogram, remaining 1900
# Converted 1470 samples to mel-spectrogram, remaining 1890
# Converted 1480 samples to mel-spectrogram, remaining 1880
# Converted 1490 samples to mel-spectrogram, remaining 1870
# Converted 1500 samples to mel-spectrogram, remaining 1860
# Converted 1510 samples to mel-spectrogram, remaining 1850
# Converted 1520 samples to mel-spectrogram, remaining 1840
# Converted 1530 samples to mel-spectrogram, remaining 1830
# Converted 1540 samples to mel-spectrogram, remaining 1820
# Converted 1550 samples to mel-spectrogram, remaining 1810
# Converted 1560 samples to mel-spectrogram, remaining 1800
# Converted 1570 samples to mel-spectrogram, remaining 1790
# Converted 1580 samples to mel-spectrogram, remaining 1780
# Converted 1590 samples to mel-spectrogram, remaining 1770
# Converted 1600 samples to mel-spectrogram, remaining 1760
# Converted 1610 samples to mel-spectrogram, remaining 1750
# Converted 1620 samples to mel-spectrogram, remaining 1740
# Converted 1630 samples to mel-spectrogram, remaining 1730
# Converted 1640 samples to mel-spectrogram, remaining 1720
# Converted 1650 samples to mel-spectrogram, remaining 1710
# Converted 1660 samples to mel-spectrogram, remaining 1700
# Converted 1670 samples to mel-spectrogram, remaining 1690
# Converted 1680 samples to mel-spectrogram, remaining 1680
# Converted 1690 samples to mel-spectrogram, remaining 1670
# Converted 1700 samples to mel-spectrogram, remaining 1660
# Converted 1710 samples to mel-spectrogram, remaining 1650
# Converted 1720 samples to mel-spectrogram, remaining 1640
# Converted 1730 samples to mel-spectrogram, remaining 1630
# Converted 1740 samples to mel-spectrogram, remaining 1620
# Converted 1750 samples to mel-spectrogram, remaining 1610
# Converted 1760 samples to mel-spectrogram, remaining 1600
# Converted 1770 samples to mel-spectrogram, remaining 1590
# Converted 1780 samples to mel-spectrogram, remaining 1580
# Converted 1790 samples to mel-spectrogram, remaining 1570
# Converted 1800 samples to mel-spectrogram, remaining 1560
# Converted 1810 samples to mel-spectrogram, remaining 1550
# Converted 1820 samples to mel-spectrogram, remaining 1540
# Converted 1830 samples to mel-spectrogram, remaining 1530
# Converted 1840 samples to mel-spectrogram, remaining 1520
# Converted 1850 samples to mel-spectrogram, remaining 1510
# Converted 1860 samples to mel-spectrogram, remaining 1500
# Converted 1870 samples to mel-spectrogram, remaining 1490
# Converted 1880 samples to mel-spectrogram, remaining 1480
# Converted 1890 samples to mel-spectrogram, remaining 1470
# Converted 1900 samples to mel-spectrogram, remaining 1460
# Converted 1910 samples to mel-spectrogram, remaining 1450
# Converted 1920 samples to mel-spectrogram, remaining 1440
# Converted 1930 samples to mel-spectrogram, remaining 1430
# Converted 1940 samples to mel-spectrogram, remaining 1420
# Converted 1950 samples to mel-spectrogram, remaining 1410
# Converted 1960 samples to mel-spectrogram, remaining 1400
# Converted 1970 samples to mel-spectrogram, remaining 1390
# Converted 1980 samples to mel-spectrogram, remaining 1380
# Converted 1990 samples to mel-spectrogram, remaining 1370
# Converted 2000 samples to mel-spectrogram, remaining 1360
# Converted 2010 samples to mel-spectrogram, remaining 1350
# Converted 2020 samples to mel-spectrogram, remaining 1340
# Converted 2030 samples to mel-spectrogram, remaining 1330
# Converted 2040 samples to mel-spectrogram, remaining 1320
# Converted 2050 samples to mel-spectrogram, remaining 1310
# Converted 2060 samples to mel-spectrogram, remaining 1300
# Converted 2070 samples to mel-spectrogram, remaining 1290
# Converted 2080 samples to mel-spectrogram, remaining 1280
# Converted 2090 samples to mel-spectrogram, remaining 1270
# Converted 2100 samples to mel-spectrogram, remaining 1260
# Converted 2110 samples to mel-spectrogram, remaining 1250
# Converted 2120 samples to mel-spectrogram, remaining 1240
# Converted 2130 samples to mel-spectrogram, remaining 1230
# Converted 2140 samples to mel-spectrogram, remaining 1220
# Converted 2150 samples to mel-spectrogram, remaining 1210
# Converted 2160 samples to mel-spectrogram, remaining 1200
# Converted 2170 samples to mel-spectrogram, remaining 1190
# Converted 2180 samples to mel-spectrogram, remaining 1180
# Converted 2190 samples to mel-spectrogram, remaining 1170
# Converted 2200 samples to mel-spectrogram, remaining 1160
# Converted 2210 samples to mel-spectrogram, remaining 1150
# Converted 2220 samples to mel-spectrogram, remaining 1140
# Converted 2230 samples to mel-spectrogram, remaining 1130
# Converted 2240 samples to mel-spectrogram, remaining 1120
# Converted 2250 samples to mel-spectrogram, remaining 1110
# Converted 2260 samples to mel-spectrogram, remaining 1100
# Converted 2270 samples to mel-spectrogram, remaining 1090
# Converted 2280 samples to mel-spectrogram, remaining 1080
# Converted 2290 samples to mel-spectrogram, remaining 1070
# Converted 2300 samples to mel-spectrogram, remaining 1060
# Converted 2310 samples to mel-spectrogram, remaining 1050
# Converted 2320 samples to mel-spectrogram, remaining 1040
# Converted 2330 samples to mel-spectrogram, remaining 1030
# Converted 2340 samples to mel-spectrogram, remaining 1020
# Converted 2350 samples to mel-spectrogram, remaining 1010
# Converted 2360 samples to mel-spectrogram, remaining 1000
# Converted 2370 samples to mel-spectrogram, remaining 990
# Converted 2380 samples to mel-spectrogram, remaining 980
# Converted 2390 samples to mel-spectrogram, remaining 970
# Converted 2400 samples to mel-spectrogram, remaining 960
# Converted 2410 samples to mel-spectrogram, remaining 950
# Converted 2420 samples to mel-spectrogram, remaining 940
# Converted 2430 samples to mel-spectrogram, remaining 930
# Converted 2440 samples to mel-spectrogram, remaining 920
# Converted 2450 samples to mel-spectrogram, remaining 910
# Converted 2460 samples to mel-spectrogram, remaining 900
# Converted 2470 samples to mel-spectrogram, remaining 890
# Converted 2480 samples to mel-spectrogram, remaining 880
# Converted 2490 samples to mel-spectrogram, remaining 870
# Converted 2500 samples to mel-spectrogram, remaining 860
# Converted 2510 samples to mel-spectrogram, remaining 850
# Converted 2520 samples to mel-spectrogram, remaining 840
# Converted 2530 samples to mel-spectrogram, remaining 830
# Converted 2540 samples to mel-spectrogram, remaining 820
# Converted 2550 samples to mel-spectrogram, remaining 810
# Converted 2560 samples to mel-spectrogram, remaining 800
# Converted 2570 samples to mel-spectrogram, remaining 790
# Converted 2580 samples to mel-spectrogram, remaining 780
# Converted 2590 samples to mel-spectrogram, remaining 770
# Converted 2600 samples to mel-spectrogram, remaining 760
# Converted 2610 samples to mel-spectrogram, remaining 750
# Converted 2620 samples to mel-spectrogram, remaining 740
# Converted 2630 samples to mel-spectrogram, remaining 730
# Converted 2640 samples to mel-spectrogram, remaining 720
# Converted 2650 samples to mel-spectrogram, remaining 710
# Converted 2660 samples to mel-spectrogram, remaining 700
# Converted 2670 samples to mel-spectrogram, remaining 690
# Converted 2680 samples to mel-spectrogram, remaining 680
# Converted 2690 samples to mel-spectrogram, remaining 670
# Converted 2700 samples to mel-spectrogram, remaining 660
# Converted 2710 samples to mel-spectrogram, remaining 650
# Converted 2720 samples to mel-spectrogram, remaining 640
# Converted 2730 samples to mel-spectrogram, remaining 630
# Converted 2740 samples to mel-spectrogram, remaining 620
# Converted 2750 samples to mel-spectrogram, remaining 610
# Converted 2760 samples to mel-spectrogram, remaining 600
# Converted 2770 samples to mel-spectrogram, remaining 590
# Converted 2780 samples to mel-spectrogram, remaining 580
# Converted 2790 samples to mel-spectrogram, remaining 570
# Converted 2800 samples to mel-spectrogram, remaining 560
# Converted 2810 samples to mel-spectrogram, remaining 550
# Converted 2820 samples to mel-spectrogram, remaining 540
# Converted 2830 samples to mel-spectrogram, remaining 530
# Converted 2840 samples to mel-spectrogram, remaining 520
# Converted 2850 samples to mel-spectrogram, remaining 510
# Converted 2860 samples to mel-spectrogram, remaining 500
# Converted 2870 samples to mel-spectrogram, remaining 490
# Converted 2880 samples to mel-spectrogram, remaining 480
# Converted 2890 samples to mel-spectrogram, remaining 470
# Converted 2900 samples to mel-spectrogram, remaining 460
# Converted 2910 samples to mel-spectrogram, remaining 450
# Converted 2920 samples to mel-spectrogram, remaining 440
# Converted 2930 samples to mel-spectrogram, remaining 430
# Converted 2940 samples to mel-spectrogram, remaining 420
# Converted 2950 samples to mel-spectrogram, remaining 410
# Converted 2960 samples to mel-spectrogram, remaining 400
# Converted 2970 samples to mel-spectrogram, remaining 390
# Converted 2980 samples to mel-spectrogram, remaining 380
# Converted 2990 samples to mel-spectrogram, remaining 370
# Converted 3000 samples to mel-spectrogram, remaining 360
# Converted 3010 samples to mel-spectrogram, remaining 350
# Converted 3020 samples to mel-spectrogram, remaining 340
# Converted 3030 samples to mel-spectrogram, remaining 330
# Converted 3040 samples to mel-spectrogram, remaining 320
# Converted 3050 samples to mel-spectrogram, remaining 310
# Converted 3060 samples to mel-spectrogram, remaining 300
# Converted 3070 samples to mel-spectrogram, remaining 290
# Converted 3080 samples to mel-spectrogram, remaining 280
# Converted 3090 samples to mel-spectrogram, remaining 270
# Converted 3100 samples to mel-spectrogram, remaining 260
# Converted 3110 samples to mel-spectrogram, remaining 250
# Converted 3120 samples to mel-spectrogram, remaining 240
# Converted 3130 samples to mel-spectrogram, remaining 230
# Converted 3140 samples to mel-spectrogram, remaining 220
# Converted 3150 samples to mel-spectrogram, remaining 210
# Converted 3160 samples to mel-spectrogram, remaining 200
# Converted 3170 samples to mel-spectrogram, remaining 190
# Converted 3180 samples to mel-spectrogram, remaining 180
# Converted 3190 samples to mel-spectrogram, remaining 170
# Converted 3200 samples to mel-spectrogram, remaining 160
# Converted 3210 samples to mel-spectrogram, remaining 150
# Converted 3220 samples to mel-spectrogram, remaining 140
# Converted 3230 samples to mel-spectrogram, remaining 130
# Converted 3240 samples to mel-spectrogram, remaining 120
# Converted 3250 samples to mel-spectrogram, remaining 110
# Converted 3260 samples to mel-spectrogram, remaining 100
# Converted 3270 samples to mel-spectrogram, remaining 90
# Converted 3280 samples to mel-spectrogram, remaining 80
# Converted 3290 samples to mel-spectrogram, remaining 70
# Converted 3300 samples to mel-spectrogram, remaining 60
# Converted 3310 samples to mel-spectrogram, remaining 50
# Converted 3320 samples to mel-spectrogram, remaining 40
# Converted 3330 samples to mel-spectrogram, remaining 30
# Converted 3340 samples to mel-spectrogram, remaining 20
# Converted 3350 samples to mel-spectrogram, remaining 10

# %%
x_train_flat_mel = mel_spectro.reshape(-1, 64, 188, 1)
aug_flat_mel = aug_mel.reshape(-1, 64, 188, 1)

# %%
all_samples_mel_x = np.concatenate([x_train_flat_mel, aug_flat_mel], axis=0)
all_samples_mel_y = np.tile(y_train, 1 + 1)

# %%
indices_mel = np.arange(all_samples_mel_x.shape[0])
np.random.shuffle(indices_mel)

x_train_mel = all_samples_mel_x[indices_mel]
y_train_mel = all_samples_mel_y[indices_mel]
# Out:
# (6720, 64, 188, 1)
